# %% [markdown]
# # Project 1
#
# Live Project: Discovering Disease Outbreaks from News Headlines
#
# Author: Bowden Wise (wisegb@ge.com)

# %%
import pandas as pd
import re
import geonamescache

# %% [markdown]
# # Prep
#
# Utilize the [geonamescache](https://pypi.org/project/geonamescache/#:~:text=A%20Python%20library%20that%20provides,include%20population%20and%20geographic%20data.) API to obtain a list of countries and cities
#
# The list of cities and countries are sorted by lenght (descending) so that when searching heeadlines for matches, the longest matching string is found.

# %%
gc = geonamescache.GeonamesCache()

# %%
city_names = []

for key, value in gc.get_cities().items(): 
    #print(value["name"])
    city_names.append(value["name"])

print("Loaded", len(city_names), " cities")
#print(city_names)
sorted_cities = sorted(city_names, key=len,reverse=True)
# Out:
# Loaded 24336  cities

# %%
country_names = []

for key, value in gc.get_countries().items(): 
    #print(value["name"])
    country_names.append(value["name"])
    
print("Loaded", len(country_names), " countries")
sorted_countries = sorted(country_names, key=len,reverse=True)
#print(sorted_countries)
# Out:
# Loaded 252  countries

# %% [markdown]
# # Regular Expression
#
# Leverage python [re](https://docs.python.org/3/library/re.html) to facillitate searching for countries and cities.
#
# The search method may be used to search for patterns. The match object returned is None if no matches are found. If a match is found, the group() method may be used to return the part of the string where the match occured.
#
# Below we define two functions to perform a search for a city or country given a headline.

# %%
regexp_countries = re.compile(r'(?:{})'.format('|'.join(map(re.escape, sorted_countries))))
regexp_cities = re.compile(r'(?:{})'.format('|'.join(map(re.escape, sorted_cities))))

# %%
# Much faster since compiled
def match_cities(text):
    match = None
    m=regexp_cities.search(text)
    if m is not None:
        match = m.group(0)
    return match

def match_countries(text):
    match = None
    m=regexp_countries.search(text)
    if m is not None:
        match = m.group(0)
    return match

# %%
# Find New York not York
# Sort cities by longest first

def match_cities_naive(text):
    for city in sorted_cities:
        #if (city == "Miami"): print("**")
        raw_search_string = r"\b" + city + r"\b"
        match = re.search(raw_search_string, text, flags=re.IGNORECASE)
        #if (city == "Miami"): print("**", city, text, match)
        if (match is not None):
            return city
    return None

def match_countries_naive(text):
    for country in sorted_countries:
        raw_search_string = r"\b" + country + r"\b"
        match = re.search(raw_search_string, text, flags=re.IGNORECASE)
        if (match is not None):
            return country
    return None

# %% [markdown]
# # Build Data Frame
#
# Here we build a data frame containing 3 columns:
# - headline
# - countries
# - cities

# %% [markdown]
# ## Load headlines from the headlines.txt filename

# %%
headlines_filename = "../data/headlines.txt"

headlines = []

with open (headlines_filename, "r") as f:
    for line in f:
        #print(line.strip())
        headlines.append(line.strip())
        
print(len(headlines), " headlines read")
# Out:
# 650  headlines read

# %% [markdown]
# ## Create the data frame
#
# Use the apply method to create the columns for countries and cities by calling our match functions defined above.

# %%
# Create data frame
df = pd.DataFrame()
df["headline"] = headlines
df["countries"] = df["headline"].apply(lambda h: match_countries(h))
df["cities"] = df["headline"].apply(lambda h: match_cities(h))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 3 columns):
# headline     650 non-null object
# countries    16 non-null object
# cities       610 non-null object
# dtypes: object(3)
# memory usage: 15.4+ KB

# %%
df
# Out:
#                                               headline countries  \
# 0                             Zika Outbreak Hits Miami      None
# 1                      Could Zika Reach New York City?      None
# 2                    First Case of Zika in Miami Beach      None
# 3              Mystery Virus Spreads in Recife, Brazil    Brazil
# 4              Dallas man comes down with case of Zika      None
# ..                                                 ...       ...
# 645  Rumors about Rabies spreading in Jerusalem hav...      None
# 646              More Zika patients reported in Indang      None
# 647  Suva authorities confirmed the spread of Rotav...      None
# 648         More Zika patients reported in Bella Vista      None
# 649                     Zika Outbreak in Wichita Falls      None
#
#             cities
# 0            Miami
# 1    New York City
# 2      Miami Beach
# 3           Recife
# 4           Dallas
# ..             ...
# 645      Jerusalem
# 646         Indang
# 647           Suva
# 648    Bella Vista
# 649  Wichita Falls
#
# [650 rows x 3 columns]

# %% [markdown]
# # Review Results

# %%
# Find rows where countries is Brazil
df_country_rows = df [df["countries"] == "Brazil"]
df_country_rows
# Out:
#                                    headline countries      cities
# 3   Mystery Virus Spreads in Recife, Brazil    Brazil      Recife
# 44      Zika outbreak in Piracicaba, Brazil    Brazil  Piracicaba
# 78         Student sick in Campinas, Brazil    Brazil    Campinas

# %%
# Find rows where countries is not null
bool_series = pd.notnull(df["countries"]) 
df[bool_series]
# Out:
#                                               headline  countries  \
# 3              Mystery Virus Spreads in Recife, Brazil     Brazil
# 25      Zika cases in Vietnam's Ho Chi Minh City surge    Vietnam
# 30                      Thailand-Zika Virus in Bangkok   Thailand
# 44                 Zika outbreak in Piracicaba, Brazil     Brazil
# 58                    Zika surfaces in Klang, Malaysia   Malaysia
# 59   Rumors about Meningitis spreading in Guatemala...  Guatemala
# 77                  Belize City under threat from Zika     Belize
# 78                    Student sick in Campinas, Brazil     Brazil
# 83                Zika outbreak spreads to Mexico City     Mexico
# 124           New Zika Case in Kota Kinabalu, Malaysia   Malaysia
# 127                 Zika reaches Johor Bahru, Malaysia   Malaysia
# 131                    Norovirus Exposure in Hong Kong  Hong Kong
# 155                    Outbreak of Zika in Panama City     Panama
# 169                  Zika cases in Singapore reach 393  Singapore
# 267  More people in Indianapolis are infected with ...      India
# 576             Panama City’s first Zika related death     Panama
#
#                cities
# 3              Recife
# 25   Ho Chi Minh City
# 30            Bangkok
# 44         Piracicaba
# 58              Klang
# 59     Guatemala City
# 77        Belize City
# 78           Campinas
# 83        Mexico City
# 124     Kota Kinabalu
# 127       Johor Bahru
# 131         Hong Kong
# 155       Panama City
# 169         Singapore
# 267      Indianapolis
# 576       Panama City

# %%
# Find rows where cities is not null
bool_series = pd.isnull(df["cities"]) 
df[bool_series]
# Out:
#                                               headline countries cities
# 7                Geneve Scientists Battle to Find Cure      None   None
# 17                       Louisiana Zika cases up to 26      None   None
# 19                 Zika infects pregnant woman in Cebu      None   None
# 63   Carnival under threat in Rio De Janeiro due to...      None   None
# 73                          Zika case reported in Oton      None   None
# 82       Hepatitis B Vaccine is now Required in Quebec      None   None
# 86                    Visitor to Cucuta contracts Zika      None   None
# 88            Maka City Experiences Influenza Outbreak      None   None
# 115                  Spreading Zika ruining Cancun fun      None   None
# 116             Cancun hit by Outbreak of Party Fever!      None   None
# 139             More Zika patients reported in Mcallen      None   None
# 168                      Zika Troubles come to Niteroi      None   None
# 199         More Zika patients reported in Joao Pessoa      None   None
# 233  More people in Mclean are infected with Hepati...      None   None
# 257          Yulee takes a hit from Spreading Sickness      None   None
# 287            More Zika patients reported in Camacari      None   None
# 339              Zika Troubles come to Padre Las Casas      None   None
# 342  Rumors about Influenza Spreading in Dobbs Ferr...      None   None
# 352                         Outbreak of Zika in Destin      None   None
# 366  More people in Huron are infected with Dengue ...      None   None
# 429           Spike of Meningitis Cases in Druid Hills      None   None
# 480            More Zika patients reported in Custodia      None   None
# 508        Fort Belvoir tests new cure for Hepatitis C      None   None
# 509  More people in Oak Brook are infected with Res...      None   None
# 516                       Outbreak of Zika in Hutchins      None   None
# 520       Longwood volunteers spreading Zika awareness      None   None
# 522  Authorities are Worried about the Spread of Tu...      None   None
# 523                   Zika symptoms spotted in Quixere      None   None
# 524                New medicine wipes out HIV in Kihei      None   None
# 539                     Zika case reported in Medellin      None   None
# 549                      Zika Reported in Ciudad Acuna      None   None
# 559            Kedougou tests new cure for Hepatitis C      None   None
# 567                                 Measles Hits Davos      None   None
# 582        Spike of Hepatitis E Cases in Morehead City      None   None
# 585                       Outbreak of Zika in Alvorada      None   None
# 598  Schools in Coamo Closed Due to Rhinovirus Outb...      None   None
# 599                           Zika arrives in Dangriga      None   None
# 628                    Zika case reported in Antioquia      None   None
# 630               Chikungunya has not Left Pismo Beach      None   None
# 631                            Zika spreads to La Joya      None   None

# %% [markdown]
# # Future Work
#
# Note geonamescache city names include foreign spellings e.g., Québec

# %%
m = match_cities("Quebec")
print(m)
# Out:
# None

# %%
# Qu\u00e9bec
m = match_cities("Qu\u00e9bec")
print(m)
# Out:
# Québec
